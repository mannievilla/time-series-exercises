# %%
import pandas as pd

# %%
df = pd.read_csv('https://query.data.world/s/z2m5rsj3425sc3onhiozmlggz4cwmm?dws=00000')

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
import requests

# %%
response = requests.get('http://aphorisms.glitch.me')

# %%
response
# Out:
# <Response [200]>

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"quote":"To riff off of Carl Sagan, programming is a humbling and character-building experience.","author":"Safia Abdalla"}'

# %%
response.json()
# Out:
# {'quote': 'To riff off of Carl Sagan, programming is a humbling and character-building experience.',
#  'author': 'Safia Abdalla'}

# %%
quote = response.json()

# %%
quote['author']
# Out:
# 'Safia Abdalla'

# %%
quote['quote']
# Out:
# 'To riff off of Carl Sagan, programming is a humbling and character-building experience.'

# %% [markdown]
# ## Swapi API

# %%
requests.get('https://swapi.dev/api')
# Out:
# <Response [200]>

# %%
response = requests.get('https://swapi.dev/api')
response.text
# Out:
# '{"people":"https://swapi.dev/api/people/","planets":"https://swapi.dev/api/planets/","films":"https://swapi.dev/api/films/","species":"https://swapi.dev/api/species/","vehicles":"https://swapi.dev/api/vehicles/","starships":"https://swapi.dev/api/starships/"}'

# %%
response.json()
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
data = response.json()
data
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
people = requests.get(data['people'])
people
# Out:
# <Response [200]>

# %%
people.json()
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
i = 1
people_list = []


while i < 10:
    
    peeps_data = requests.get(f'https://swapi.dev/api/people/?page={i}')
    
    people_list.append(peeps_data)
    
    i += 1

# %%
people_list[0].json()['results']
# Out:
# [{'name': 'Luke Skywalker',
#   'height': '172',
#   'mass': '77',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '19BBY',
#   'gender': 'male',
#   'homeworld': 'https://swapi.dev/api/planets/1/',
#   'films': ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['https://swapi.dev/api/vehicles/14/',
#    'https://swapi.dev/api/vehicles/30/'],
#   'starships': ['https://swapi.dev/api/starships/12/',
#    'https://swapi.dev/api/starships/22/'],
#   'created': '2014-12-09T13:50:51.644000Z',
#   'edited': '2014-12-20T21:17:56.891000Z',
#   'url': 'https://swapi.dev/api/people/1/'},
#  {'name': 'C-3PO',
#   'height': '167',
#   'mass': '75',
#   'hair_color': 'n/a',
#   'skin_color': 'gold',
#   'eye_color': 'yellow',
#   'birth_year': '112BBY',
#   'gender': 'n/a',
# ...

# %%
people_list
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
dict_list = []

for dicti in people_list:
    
    people_page = pd.DataFrame(dicti.json()['results'])
    dict_list.append(people_page)

# %%
dict_list[1].head()
# Out:
#                name height     mass    hair_color skin_color eye_color  \
# 0  Anakin Skywalker    188       84         blond       fair      blue
# 1    Wilhuff Tarkin    180  unknown  auburn, grey       fair      blue
# 2         Chewbacca    228      112         brown    unknown      blue
# 3          Han Solo    180       80         brown       fair     brown
# 4            Greedo    173       74           n/a      green     black
#
#   birth_year gender                          homeworld  \
# 0    41.9BBY   male   https://swapi.dev/api/planets/1/
# 1      64BBY   male  https://swapi.dev/api/planets/21/
# 2     200BBY   male  https://swapi.dev/api/planets/14/
# 3      29BBY   male  https://swapi.dev/api/planets/22/
# 4      44BBY   male  https://swapi.dev/api/planets/23/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/4/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# ...

# %%
df = pd.concat(dict_list, axis=0, ignore_index=True)

# %%
df.head()
# Out:
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        n/a         gold    yellow     112BBY
# 2           R2-D2     96   32        n/a  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     n/a  https://swapi.dev/api/planets/1/
# 2     n/a  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# ...

# %%
len(df.homeworld.value_counts().to_list())
# Out:
# 49

# %%
planets = requests.get('https://swapi.dev/api/planets/')
planets
# Out:
# <Response [200]>

# %%
planets.json()['count']
# Out:
# 60

# %%
i = 1
planet_list = []


while i < 7:
    
    planets_data = requests.get(f'https://swapi.dev/api/planets/?page={i}')
    
    planet_list.append(planets_data)
    
    i += 1

# %%
planet_list[0].json()['results']
# Out:
# [{'name': 'Tatooine',
#   'rotation_period': '23',
#   'orbital_period': '304',
#   'diameter': '10465',
#   'climate': 'arid',
#   'gravity': '1 standard',
#   'terrain': 'desert',
#   'surface_water': '1',
#   'population': '200000',
#   'residents': ['https://swapi.dev/api/people/1/',
#    'https://swapi.dev/api/people/2/',
#    'https://swapi.dev/api/people/4/',
#    'https://swapi.dev/api/people/6/',
#    'https://swapi.dev/api/people/7/',
#    'https://swapi.dev/api/people/8/',
#    'https://swapi.dev/api/people/9/',
#    'https://swapi.dev/api/people/11/',
#    'https://swapi.dev/api/people/43/',
#    'https://swapi.dev/api/people/62/'],
#   'films': ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   'created': '2014-12-09T13:50:49.641000Z',
#   'edited': '2014-12-20T20:58:18.411000Z',
#   'url': 'https://swapi.dev/api/planets/1/'},
# ...

# %%
dict_list = []

for dicti in planet_list:
    
    planet_page = pd.DataFrame(dicti.json()['results'])
    dict_list.append(planet_page)

# %%
planet_df = pd.concat(dict_list, axis=0, ignore_index=True)

# %%
planet_df.head()
# Out:
#        name rotation_period orbital_period diameter              climate  \
# 0  Tatooine              23            304    10465                 arid
# 1  Alderaan              24            364    12500            temperate
# 2  Yavin IV              24           4818    10200  temperate, tropical
# 3      Hoth              23            549     7200               frozen
# 4   Dagobah              23            341     8900                murky
#
#         gravity                             terrain surface_water  population  \
# 0    1 standard                              desert             1      200000
# 1    1 standard               grasslands, mountains            40  2000000000
# 2    1 standard                 jungle, rainforests             8        1000
# 3  1.1 standard  tundra, ice caves, mountain ranges           100     unknown
# 4           N/A                      swamp, jungles             8     unknown
#
#                                            residents  \
# ...

# %%
starships = requests.get('https://swapi.dev/api/starships/')
starships
# Out:
# <Response [200]>

# %%
df.head()
# Out:
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        n/a         gold    yellow     112BBY
# 2           R2-D2     96   32        n/a  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     n/a  https://swapi.dev/api/planets/1/
# 2     n/a  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# ...

# %%
starships.json()
# Out:
# {'count': 36,
#  'next': 'https://swapi.dev/api/starships/?page=2',
#  'previous': None,
#  'results': [{'name': 'CR90 corvette',
#    'model': 'CR90 corvette',
#    'manufacturer': 'Corellian Engineering Corporation',
#    'cost_in_credits': '3500000',
#    'length': '150',
#    'max_atmosphering_speed': '950',
#    'crew': '30-165',
#    'passengers': '600',
#    'cargo_capacity': '3000000',
#    'consumables': '1 year',
#    'hyperdrive_rating': '2.0',
#    'MGLT': '60',
#    'starship_class': 'corvette',
#    'pilots': [],
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-10T14:20:33.369000Z',
#    'edited': '2014-12-20T21:23:49.867000Z',
#    'url': 'https://swapi.dev/api/starships/2/'},
#   {'name': 'Star Destroyer',
#    'model': 'Imperial I-class Star Destroyer',
#    'manufacturer': 'Kuat Drive Yards',
#    'cost_in_credits': '150000000',
#    'length': '1,600',
# ...

# %%
i = 1
ship_list = []


while i < 5:
    
    ship_data = requests.get(f'https://swapi.dev/api/starships/?page={i}')
    
    ship_list.append(ship_data)
    
    i += 1

# %%
dict_list = []

for dicti in ship_list:
    
    ship_page = pd.DataFrame(dicti.json()['results'])
    dict_list.append(ship_page)

# %%
ship_df = pd.concat(dict_list, axis=0, ignore_index=True)

# %%
ship_df.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# ...

# %%
df.films
# Out:
# 0     [https://swapi.dev/api/films/1/, https://swapi...
# 1     [https://swapi.dev/api/films/1/, https://swapi...
# 2     [https://swapi.dev/api/films/1/, https://swapi...
# 3     [https://swapi.dev/api/films/1/, https://swapi...
# 4     [https://swapi.dev/api/films/1/, https://swapi...
#                             ...
# 77                     [https://swapi.dev/api/films/6/]
# 78                     [https://swapi.dev/api/films/6/]
# 79    [https://swapi.dev/api/films/1/, https://swapi...
# 80    [https://swapi.dev/api/films/5/, https://swapi...
# 81                     [https://swapi.dev/api/films/6/]
# Name: films, Length: 82, dtype: object

# %%
films = requests.get('https://swapi.dev/api/films/')
films
# Out:
# <Response [200]>

# %%
films.json()
# Out:
# {'count': 6,
#  'next': None,
#  'previous': None,
#  'results': [{'title': 'A New Hope',
#    'episode_id': 4,
#    'opening_crawl': "It is a period of civil war.\r\nRebel spaceships, striking\r\nfrom a hidden base, have won\r\ntheir first victory against\r\nthe evil Galactic Empire.\r\n\r\nDuring the battle, Rebel\r\nspies managed to steal secret\r\nplans to the Empire's\r\nultimate weapon, the DEATH\r\nSTAR, an armored space\r\nstation with enough power\r\nto destroy an entire planet.\r\n\r\nPursued by the Empire's\r\nsinister agents, Princess\r\nLeia races home aboard her\r\nstarship, custodian of the\r\nstolen plans that can save her\r\npeople and restore\r\nfreedom to the galaxy....",
#    'director': 'George Lucas',
#    'producer': 'Gary Kurtz, Rick McCallum',
#    'release_date': '1977-05-25',
#    'characters': ['https://swapi.dev/api/people/1/',
#     'https://swapi.dev/api/people/2/',
#     'https://swapi.dev/api/people/3/',
#     'https://swapi.dev/api/people/4/',
# ...

# %%
i = 1
films_list = []


while i < 2:
    
    film_data = requests.get(f'https://swapi.dev/api/starships/?page={i}')
    
    films_list.append(film_data)
    
    i += 1

# %%
dict_list = []

for dicti in films_list:
    
    film_page = pd.DataFrame(dicti.json()['results'])
    dict_list.append(film_page)

# %%
film_df = pd.concat(dict_list, axis=0, ignore_index=True)

# %%
film_df.head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# ...

# %%
df.head()
# Out:
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        n/a         gold    yellow     112BBY
# 2           R2-D2     96   32        n/a  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     n/a  https://swapi.dev/api/planets/1/
# 2     n/a  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# ...

# %%
species = requests.get('https://swapi.dev/api/species/')
species.json()
# Out:
# {'count': 37,
#  'next': 'https://swapi.dev/api/species/?page=2',
#  'previous': None,
#  'results': [{'name': 'Human',
#    'classification': 'mammal',
#    'designation': 'sentient',
#    'average_height': '180',
#    'skin_colors': 'caucasian, black, asian, hispanic',
#    'hair_colors': 'blonde, brown, black, red',
#    'eye_colors': 'brown, blue, green, hazel, grey, amber',
#    'average_lifespan': '120',
#    'homeworld': 'https://swapi.dev/api/planets/9/',
#    'language': 'Galactic Basic',
#    'people': ['https://swapi.dev/api/people/66/',
#     'https://swapi.dev/api/people/67/',
#     'https://swapi.dev/api/people/68/',
#     'https://swapi.dev/api/people/74/'],
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/4/',
#     'https://swapi.dev/api/films/5/',
#     'https://swapi.dev/api/films/6/'],
#    'created': '2014-12-10T13:52:11.567000Z',
# ...

# %%
len(species.json()['results'])
# Out:
# 10

# %%
i = 1
species_list = []


while i < 5:
    
    species_data = requests.get(f'https://swapi.dev/api/species/?page={i}')
    
    species_list.append(species_data)
    
    i += 1

# %%
dict_list = []

for dicti in species_list:
    
    species_page = pd.DataFrame(dicti.json()['results'])
    dict_list.append(species_page)

# %%
species_df = pd.concat(dict_list, axis=0, ignore_index=True)

# %%
species_df.head()
# Out:
#      name classification designation average_height  \
# 0   Human         mammal    sentient            180
# 1   Droid     artificial    sentient            n/a
# 2  Wookie         mammal    sentient            210
# 3  Rodian       sentient   reptilian            170
# 4    Hutt      gastropod    sentient            300
#
#                          skin_colors                hair_colors  \
# 0  caucasian, black, asian, hispanic  blonde, brown, black, red
# 1                                n/a                        n/a
# 2                               gray               black, brown
# 3                        green, blue                        n/a
# 4                  green, brown, tan                        n/a
#
#                                 eye_colors average_lifespan  \
# 0   brown, blue, green, hazel, grey, amber              120
# 1                                      n/a       indefinite
# 2  blue, green, yellow, brown, golden, red              400
# ...

# %%
vehicles = requests.get('https://swapi.dev/api/vehicles/')
vehicles.json()
# Out:
# {'count': 39,
#  'next': 'https://swapi.dev/api/vehicles/?page=2',
#  'previous': None,
#  'results': [{'name': 'Sand Crawler',
#    'model': 'Digger Crawler',
#    'manufacturer': 'Corellia Mining Corporation',
#    'cost_in_credits': '150000',
#    'length': '36.8 ',
#    'max_atmosphering_speed': '30',
#    'crew': '46',
#    'passengers': '30',
#    'cargo_capacity': '50000',
#    'consumables': '2 months',
#    'vehicle_class': 'wheeled',
#    'pilots': [],
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/5/'],
#    'created': '2014-12-10T15:36:25.724000Z',
#    'edited': '2014-12-20T21:30:21.661000Z',
#    'url': 'https://swapi.dev/api/vehicles/4/'},
#   {'name': 'T-16 skyhopper',
#    'model': 'T-16 skyhopper',
#    'manufacturer': 'Incom Corporation',
#    'cost_in_credits': '14500',
#    'length': '10.4 ',
#    'max_atmosphering_speed': '1200',
#    'crew': '1',
#    'passengers': '1',
#    'cargo_capacity': '50',
#    'consumables': '0',
# ...

# %%
i = 1
vehicles_list = []


while i < 5:
    
    vehicles_data = requests.get(f'https://swapi.dev/api/vehicles/?page={i}')
    
    vehicles_list.append(vehicles_data)
    
    i += 1

# %%
dict_list = []

for dicti in vehicles_list:
    
    vehicles_page = pd.DataFrame(dicti.json()['results'])
    dict_list.append(vehicles_page)

# %%
vehicles_df = pd.concat(dict_list, axis=0, ignore_index=True)

# %%
vehicles_df.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer cost_in_credits length max_atmosphering_speed  \
# 0  Corellia Mining Corporation          150000  36.8                      30
# 1            Incom Corporation           14500  10.4                    1200
# 2         SoroSuub Corporation           10550   3.4                     250
# 3         Sienar Fleet Systems         unknown    6.4                   1200
# 4            Incom corporation         unknown    4.5                    650
#
#   crew passengers cargo_capacity consumables  vehicle_class  \
# 0   46         30          50000    2 months        wheeled
# ...

# %%
df
# Out:
#                name height mass hair_color    skin_color      eye_color  \
# 0    Luke Skywalker    172   77      blond          fair           blue
# 1             C-3PO    167   75        n/a          gold         yellow
# 2             R2-D2     96   32        n/a   white, blue            red
# 3       Darth Vader    202  136       none         white         yellow
# 4       Leia Organa    150   49      brown         light          brown
# ..              ...    ...  ...        ...           ...            ...
# 77         Grievous    216  159       none  brown, white  green, yellow
# 78          Tarfful    234  136      brown         brown           blue
# 79  Raymus Antilles    188   79      brown         light          brown
# 80        Sly Moore    178   48       none          pale          white
# 81       Tion Medon    206   80       none          grey          black
#
#    birth_year  gender                          homeworld  \
# ...

# %%
list(df.homeworld.unique())
# Out:
# ['https://swapi.dev/api/planets/1/',
#  'https://swapi.dev/api/planets/8/',
#  'https://swapi.dev/api/planets/2/',
#  'https://swapi.dev/api/planets/20/',
#  'https://swapi.dev/api/planets/21/',
#  'https://swapi.dev/api/planets/14/',
#  'https://swapi.dev/api/planets/22/',
#  'https://swapi.dev/api/planets/23/',
#  'https://swapi.dev/api/planets/24/',
#  'https://swapi.dev/api/planets/26/',
#  'https://swapi.dev/api/planets/28/',
#  'https://swapi.dev/api/planets/10/',
#  'https://swapi.dev/api/planets/29/',
#  'https://swapi.dev/api/planets/30/',
#  'https://swapi.dev/api/planets/6/',
#  'https://swapi.dev/api/planets/31/',
#  'https://swapi.dev/api/planets/32/',
#  'https://swapi.dev/api/planets/7/',
#  'https://swapi.dev/api/planets/33/',
#  'https://swapi.dev/api/planets/18/',
#  'https://swapi.dev/api/planets/9/',
#  'https://swapi.dev/api/planets/34/',
#  'https://swapi.dev/api/planets/35/',
#  'https://swapi.dev/api/planets/36/',
#  'https://swapi.dev/api/planets/37/',
# ...

# %%
# pd.concat([df, planet_df], join='outer', key=list(df.homeworld.unique()))

# %%
# Performing an inner merge between df and planet_df on the 'homeworld' and 'url' columns
result = pd.merge(df, planet_df, left_on='homeworld', right_on='url', how='inner')

# %%
result.T
# Out:
#                                                                 0   \
# name_x                                              Luke Skywalker
# height                                                         172
# mass                                                            77
# hair_color                                                   blond
# skin_color                                                    fair
# eye_color                                                     blue
# birth_year                                                   19BBY
# gender                                                        male
# homeworld                         https://swapi.dev/api/planets/1/
# films_x          [https://swapi.dev/api/films/1/, https://swapi...
# species                                                         []
# vehicles         [https://swapi.dev/api/vehicles/14/, https://s...
# starships        [https://swapi.dev/api/starships/12/, https://...
# ...

# %%
# calls the first value in side the list that is inside the column
result.starships.str[0]
# Out:
# 0     https://swapi.dev/api/starships/12/
# 1                                     NaN
# 2     https://swapi.dev/api/starships/13/
# 3                                     NaN
# 4                                     NaN
#                      ...
# 77                                    NaN
# 78                                    NaN
# 79    https://swapi.dev/api/starships/74/
# 80                                    NaN
# 81                                    NaN
# Name: starships, Length: 82, dtype: object

# %%
result = pd.merge(result, ship_df, left_on=result.starships.str[0], right_on='url', how='inner')

# %%
result
# Out:
#                name_x   height     mass     hair_color    skin_color  \
# 0      Luke Skywalker      172       77          blond          fair
# 1   Biggs Darklighter      183       84          black         light
# 2      Wedge Antilles      170       77          brown          fair
# 3    Jek Tono Porkins      180      110          brown          fair
# 4         Darth Vader      202      136           none         white
# 5    Anakin Skywalker      188       84          blond          fair
# 6       Padmé Amidala      185       45          brown         light
# 7        Gregar Typho      185       85          black          dark
# 8            Ric Olié      183  unknown          brown          fair
# 9      Obi-Wan Kenobi      182       77  auburn, white          fair
# 10           Plo Koon      188       80           none        orange
# 11          Chewbacca      228      112          brown       unknown
# 12           Han Solo      180       80          brown          fair
# ...

# %%
df["starships"].to_list()
# Out:
# [['https://swapi.dev/api/starships/12/',
#   'https://swapi.dev/api/starships/22/'],
#  [],
#  [],
#  ['https://swapi.dev/api/starships/13/'],
#  [],
#  [],
#  [],
#  [],
#  ['https://swapi.dev/api/starships/12/'],
#  ['https://swapi.dev/api/starships/48/',
#   'https://swapi.dev/api/starships/59/',
#   'https://swapi.dev/api/starships/64/',
#   'https://swapi.dev/api/starships/65/',
#   'https://swapi.dev/api/starships/74/'],
#  ['https://swapi.dev/api/starships/39/',
#   'https://swapi.dev/api/starships/59/',
#   'https://swapi.dev/api/starships/65/'],
#  [],
#  ['https://swapi.dev/api/starships/10/',
#   'https://swapi.dev/api/starships/22/'],
#  ['https://swapi.dev/api/starships/10/',
#   'https://swapi.dev/api/starships/22/'],
#  [],
#  [],
#  ['https://swapi.dev/api/starships/12/'],
#  ['https://swapi.dev/api/starships/12/'],
#  [],
#  [],
#  ['https://swapi.dev/api/starships/21/'],
#  [],
#  [],
#  ['https://swapi.dev/api/starships/10/'],
#  [],
#  [],
#  [],
# ...

# %%
pd.DataFrame(df["starships"].to_list(), columns=['team1', 'team2'])
